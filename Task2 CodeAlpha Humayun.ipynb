# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/Daily Household Transactions.csv')

# %%
df.head()
# Out:
#                   Date                   Mode        Category  \
# 0  20/09/2018 12:04:08                   Cash  Transportation
# 1  20/09/2018 12:03:15                   Cash            Food
# 2           19/09/2018  Saving Bank account 1    subscription
# 3  17/09/2018 23:41:17  Saving Bank account 1    subscription
# 4  16/09/2018 17:15:08                   Cash       Festivals
#
#                Subcategory                         Note  Amount  \
# 0                    Train         2 Place 5 to Place 0    30.0
# 1                   snacks  Idli medu Vada mix 2 plates    60.0
# 2                  Netflix         1 month subscription   199.0
# 3  Mobile Service Provider            Data booster pack    19.0
# 4             Ganesh Pujan                  Ganesh idol   251.0
#
#   Income/Expense Currency
# 0        Expense      INR
# 1        Expense      INR
# 2        Expense      INR
# 3        Expense      INR
# 4        Expense      INR

# %%
df.describe()
# Out:
#               Amount
# count    2461.000000
# mean     2751.145380
# std     12519.615804
# min         2.000000
# 25%        35.000000
# 50%       100.000000
# 75%       799.000000
# max    250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2461 entries, 0 to 2460
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            2461 non-null   object
#  1   Mode            2461 non-null   object
#  2   Category        2461 non-null   object
#  3   Subcategory     1826 non-null   object
#  4   Note            1940 non-null   object
#  5   Amount          2461 non-null   float64
#  6   Income/Expense  2461 non-null   object
#  7   Currency        2461 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 153.9+ KB

# %%
df.isnull().sum()
# Out:
# Date                0
# Mode                0
# Category            0
# Subcategory       635
# Note              521
# Amount              0
# Income/Expense      0
# Currency            0
# dtype: int64

# %%
df.count()
# Out:
# Date              2461
# Mode              2461
# Category          2461
# Subcategory       1826
# Note              1940
# Amount            2461
# Income/Expense    2461
# Currency          2461
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.count()
# Out:
# Date              1563
# Mode              1563
# Category          1563
# Subcategory       1563
# Note              1563
# Amount            1563
# Income/Expense    1563
# Currency          1563
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date              0
# Mode              0
# Category          0
# Subcategory       0
# Note              0
# Amount            0
# Income/Expense    0
# Currency          0
# dtype: int64

# %%
df
# Out:
#                      Date                   Mode        Category  \
# 0     20/09/2018 12:04:08                   Cash  Transportation
# 1     20/09/2018 12:03:15                   Cash            Food
# 2              19/09/2018  Saving Bank account 1    subscription
# 3     17/09/2018 23:41:17  Saving Bank account 1    subscription
# 4     16/09/2018 17:15:08                   Cash       Festivals
# ...                   ...                    ...             ...
# 2329  23/02/2015 19:37:47                   Cash  Transportation
# 2330  23/02/2015 18:39:59                   Cash         Apparel
# 2331  23/02/2015 15:43:13            Credit Card  Transportation
# 2333  19/02/2015 20:52:01                   Cash          Health
# 2334  19/02/2015 20:51:37                   Cash          Health
#
#                   Subcategory                         Note  Amount  \
# 0                       Train         2 Place 5 to Place 0    30.0
# 1                      snacks  Idli medu Vada mix 2 plates    60.0
# 2                     Netflix         1 month subscription   199.0
# 3     Mobile Service Provider            Data booster pack    19.0
# 4                Ganesh Pujan                  Ganesh idol   251.0
# ...                       ...                          ...     ...
# 2329                    Train            Place 0 to Bandra    20.0
# 2330                 Footwear                  shoe polish    20.0
# 2331                    train        to and fro Mum to BRC   526.0
# 2333                   Health                    face mask    45.0
# 2334                 Medicine                       koflet    34.0
#
#      Income/Expense Currency
# 0           Expense      INR
# 1           Expense      INR
# 2           Expense      INR
# 3           Expense      INR
# 4           Expense      INR
# ...             ...      ...
# 2329        Expense      INR
# 2330        Expense      INR
# 2331        Expense      INR
# 2333        Expense      INR
# 2334        Expense      INR
#
# [1563 rows x 8 columns]

# %%
payment_mode_counts = df['Mode'].value_counts()
payment_mode_counts.plot(kind='bar')
plt.title('Payment Mode Distribution')
plt.xlabel('Payment Mode')
plt.ylabel('Count')
plt.show()

# %%
category_counts = df['Category'].value_counts()
category_counts.plot(kind='bar')
plt.title('Category Distribution')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
df.groupby('Category')['Amount'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Expenses by Category')
# Out:
# Text(0.5, 1.0, 'Distribution of Expenses by Category')

# %%
curr_count = df['Currency'].value_counts()
curr_count.plot(kind='bar')
plt.title('Currency Distribution')
plt.xlabel('Currency')
plt.ylabel('Count')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

selected_columns = ['Amount', 'Category', 'Subcategory']
data_selected = df[selected_columns]

# %%
data_encoded = pd.get_dummies(data_selected, columns=['Category', 'Subcategory'])

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_encoded)

# %%
data_scaled_df = pd.DataFrame(data_scaled, columns=data_encoded.columns)

data_scaled_df.head()
# Out:
#      Amount  Category_Apparel  Category_Beauty  Category_Culture  \
# 0 -0.177219         -0.174135        -0.110931         -0.080244
# 1 -0.165255         -0.174135        -0.110931         -0.080244
# 2 -0.109820         -0.174135        -0.110931         -0.080244
# 3 -0.181606         -0.174135        -0.110931         -0.080244
# 4 -0.089082         -0.174135        -0.110931         -0.080244
#
#    Category_Documents  Category_Education  Category_Family  \
# 0           -0.035794           -0.107937        -0.122209
# 1           -0.035794           -0.107937        -0.122209
# 2           -0.035794           -0.107937        -0.122209
# 3           -0.035794           -0.107937        -0.122209
# 4           -0.035794           -0.107937        -0.122209
#
#    Category_Festivals  Category_Food  Category_Grooming  ...  \
# 0           -0.101699      -0.955561          -0.050653  ...
# 1           -0.101699       1.046506          -0.050653  ...
# 2           -0.101699      -0.955561          -0.050653  ...
# 3           -0.101699      -0.955561          -0.050653  ...
# 4            9.832980      -0.955561          -0.050653  ...
#
#    Subcategory_gift  Subcategory_grooming  Subcategory_home decor  \
# 0         -0.035794             -0.104862               -0.050653
# 1         -0.035794             -0.104862               -0.050653
# 2         -0.035794             -0.104862               -0.050653
# 3         -0.035794             -0.104862               -0.050653
# 4         -0.035794             -0.104862               -0.050653
#
#    Subcategory_makeup  Subcategory_medicine  Subcategory_misc  \
# 0           -0.025302             -0.035794         -0.067072
# 1           -0.025302             -0.035794         -0.067072
# 2           -0.025302             -0.035794         -0.067072
# 3           -0.025302             -0.035794         -0.067072
# 4           -0.025302             -0.035794         -0.067072
#
#    Subcategory_ropeway  Subcategory_snacks  Subcategory_train  \
# 0            -0.025302           -0.281815          -0.110931
# 1            -0.025302            3.548423          -0.110931
# 2            -0.025302           -0.281815          -0.110931
# 3            -0.025302           -0.281815          -0.110931
# 4            -0.025302           -0.281815          -0.110931
#
#    Subcategory_vegetables
# 0               -0.101699
# 1               -0.101699
# 2               -0.101699
# 3               -0.101699
# 4               -0.101699
#
# [5 rows x 104 columns]

# %%
inertia = []
for n in range(1, 11):
    kmeans = KMeans(n_clusters=n, random_state=0)
    kmeans.fit(data_scaled_df)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia)
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
optimal_clusters = 8
kmeans = KMeans(n_clusters=optimal_clusters, random_state=0)
kmeans.fit(data_scaled_df)

df['Cluster'] = kmeans.labels_
print(df.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                   Date                   Mode        Category  \
# 0  20/09/2018 12:04:08                   Cash  Transportation
# 1  20/09/2018 12:03:15                   Cash            Food
# 2           19/09/2018  Saving Bank account 1    subscription
# 3  17/09/2018 23:41:17  Saving Bank account 1    subscription
# 4  16/09/2018 17:15:08                   Cash       Festivals
#
#                Subcategory                         Note  Amount  \
# 0                    Train         2 Place 5 to Place 0    30.0
# 1                   snacks  Idli medu Vada mix 2 plates    60.0
# 2                  Netflix         1 month subscription   199.0
# 3  Mobile Service Provider            Data booster pack    19.0
# 4             Ganesh Pujan                  Ganesh idol   251.0
#
#   Income/Expense Currency  Cluster
# 0        Expense      INR        0
# 1        Expense      INR        1
# 2        Expense      INR        1
# 3        Expense      INR        1
# 4        Expense      INR        1

# %%
for cluster in range(optimal_clusters):
    print(f'Cluster {cluster}')
    print(df[df['Cluster'] == cluster].head())
# Out:
# Cluster 0
#                    Date                   Mode        Category Subcategory  \
# 0   20/09/2018 12:04:08                   Cash  Transportation       Train
# 6   14/09/2018 05:39:17                   Cash  Transportation        auto
# 7   13/09/2018 21:35:15  Saving Bank account 1  Transportation       Train
# 53  23/08/2018 21:29:52            Credit Card  Transportation       train
# 54  23/08/2018 21:29:12            Credit Card  Transportation       train
#
#                                            Note  Amount Income/Expense  \
# 0                          2 Place 5 to Place 0    30.0        Expense
# 6        Place 2 station to Permanent Residence    50.0        Expense
# 7                          2 Place 0 to Place 3    40.0        Expense
# 53  2 Place 2 to Place 3 : Sevagram express 3AC  1305.4        Expense
# 54  2 Place 3 to Place 2 : Amritsar express 3AC  1205.4        Expense
#
#    Currency  Cluster
# 0       INR        0
# 6       INR        0
# 7       INR        0
# 53      INR        0
# 54      INR        0
# Cluster 1
#                   Date                   Mode      Category  \
# 1  20/09/2018 12:03:15                   Cash          Food
# 2           19/09/2018  Saving Bank account 1  subscription
# 3  17/09/2018 23:41:17  Saving Bank account 1  subscription
# 4  16/09/2018 17:15:08                   Cash     Festivals
# 5  15/09/2018 06:34:17            Credit Card  subscription
#
#                Subcategory                                      Note  Amount  \
# 1                   snacks               Idli medu Vada mix 2 plates    60.0
# 2                  Netflix                      1 month subscription   199.0
# 3  Mobile Service Provider                         Data booster pack    19.0
# 4             Ganesh Pujan                               Ganesh idol   251.0
# 5                 Tata Sky  Permanent Residence - Tata Play recharge   200.0
#
#   Income/Expense Currency  Cluster
# 1        Expense      INR        1
# 2        Expense      INR        1
# 3        Expense      INR        1
# 4        Expense      INR        1
# 5        Expense      INR        1
# Cluster 2
#                     Date         Mode Category Subcategory  \
# 32   31/08/2018 10:01:15  Credit Card     Food      Dinner
# 48   24/08/2018 22:13:43  Credit Card     Food      Dinner
# 163             6/7/2018         Cash     Food      Dinner
# 200  28/06/2018 20:44:36  Credit Card     Food      Dinner
# 283            12/5/2018  Credit Card     Food      Dinner
#
#                    Note   Amount Income/Expense Currency  Cluster
# 32       Domino's Pizza   510.85        Expense      INR        2
# 48   Home Food Delivery  1120.00        Expense      INR        2
# 163       At restaurant   760.00        Expense      INR        2
# 200  Home Food Delivery   455.00        Expense      INR        2
# 283      Domino's Pizza   437.00        Expense      INR        2
# Cluster 3
#                      Date                   Mode Category Subcategory  \
# 1021  28/08/2017 12:06:47                   Cash  Tourism        Trip
# 1023  27/08/2017 04:44:32                   Cash  Tourism        Trip
# 1080             8/8/2017  Saving Bank account 1  Tourism        Trip
# 1137  25/07/2017 19:31:06  Saving Bank account 1  Tourism        Trip
#
#                   Note   Amount Income/Expense Currency  Cluster
# 1021      Misc expense    200.0        Expense      INR        3
# 1023      Misc expense    100.0        Expense      INR        3
# 1080  Tours and Travel  43000.0        Expense      INR        3
# 1137  Tours and Travel  20000.0        Expense      INR        3
# Cluster 4
#                    Date  Mode   Category Subcategory  \
# 36  30/08/2018 21:09:51  Cash  Household      Kirana
# 70  14/08/2018 09:50:12  Cash  Household      Kirana
# 74  13/08/2018 18:36:01  Cash  Household  home decor
# 76  13/08/2018 18:33:36  Cash  Household      Kirana
# 95             2/8/2018  Cash  Household      Kirana
#
#                          Note  Amount Income/Expense Currency  Cluster
# 36                  Supermart   343.0        Expense      INR        4
# 70       Toothpaste Patanjali   160.0        Expense      INR        4
# 74  Brass Puja plate and diva   220.0        Expense      INR        4
# 76                  Supermart   594.0        Expense      INR        4
# 95                  Supermart    18.0        Expense      INR        4
# Cluster 5
#             Date                   Mode    Category  Subcategory  \
# 1813  10/11/2016  Saving Bank account 1  Investment           RD
# 1814  10/11/2016  Saving Bank account 1  Investment          LIC
# 1821   5/11/2016  Saving Bank account 1  Investment           RD
# 1907   11/8/2016  Saving Bank account 1  Investment          LIC
# 1925   12/7/2016  Saving Bank account 1  Investment  Mutual fund
#
#                 Note   Amount Income/Expense Currency  Cluster
# 1813              RD   1000.0        Expense      INR        5
# 1814  Life Insurance  11286.0        Expense      INR        5
# 1821              RD   1000.0        Expense      INR        5
# 1907  Life Insurance  11286.0        Expense      INR        5
# 1925   Mutual fund C   1000.0        Expense      INR        5
# Cluster 6
#                     Date                   Mode   Category Subcategory  \
# 279  13/05/2018 20:16:54                   Cash  Education  Stationary
# 344  16/04/2018 22:40:53  Saving Bank account 1  Education  Stationary
# 469             6/3/2018  Saving Bank account 1  Education  Stationary
# 823  15/11/2017 20:46:34  Saving Bank account 1  Education  Stationary
# 999             5/9/2017                   Cash  Education  Stationary
#
#                   Note  Amount Income/Expense Currency  Cluster
# 279    Gel pen Refills    12.0        Expense      INR        6
# 344             3 Pens    21.0        Expense      INR        6
# 469              Xerox     4.0        Expense      INR        6
# 823  Photo paper print    45.0        Expense      INR        6
# 999  Print outs+ Xerox    50.0        Expense      INR        6
# Cluster 7
#                     Date                   Mode   Category Subcategory  \
# 73   13/08/2018 18:37:27                   Cash  Household  Appliances
# 192  30/06/2018 18:47:45  Saving Bank account 1  Household  Appliances
# 199  29/06/2018 15:28:46                   Cash  Household  Appliances
# 218  26/06/2018 17:25:23  Saving Bank account 1  Household  Appliances
# 268  15/05/2018 20:10:10  Saving Bank account 1  Household  Appliances
#
#                              Note   Amount Income/Expense Currency  Cluster
# 73   5 litres can Distilled water    100.0        Expense      INR        7
# 192                  Aqugurad PRV   1200.0        Expense      INR        7
# 199        3 bulbs 3 pencil cells    270.0        Expense      INR        7
# 218       Aqugurad water purifier  13050.0        Expense      INR        7
# 268            LG Washing Machine  21500.0        Expense      INR        7

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df['Amount'], df['Cluster'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Amount')
plt.ylabel('Cluster')
plt.title('Scatter Plot of Clusters')
plt.colorbar()
plt.show()
